# %% [markdown]
# ## SAIGE step0

# %%
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -v /media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/:/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/ \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step0_group${group}_${n}.log -v \
        createSparseGRM.R \
            --plinkFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_oddchr_pruned \
            --nThreads=1 \
            --outputPrefix=Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n} \
            --numRandomMarkerforSparseKin=2000 \
            --relatednessCutoff=0.125 &

    done
done

# %% [markdown]
# ## SAIGE step1

# %%
colname=y
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -v /media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/:/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/ \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step1_group${group}_${n}.log -v \
        step1_fitNULLGLMM.R \
            --sparseGRMFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx \
            --sparseGRMSampleIDFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx.sampleIDs.txt \
            --useSparseGRMtoFitNULL=TRUE \
            --plinkFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_oddchr_combined_4000SNP \
            --phenoFile=/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/seed_1_WES_200k_WB_tau_1_prev_0.01.pheno.evenChr_pca \
            --phenoCol=${colname} \
            --covarColList=x1,x2,PC1,PC2,PC3,PC4,PC5,PC6,PC7,PC8,PC9,PC10 \
            --sampleIDColinphenoFile=IND_ID \
            --traitType=binary \
            --isCateVarianceRatio=TRUE \
            --nThreads=1 \
            --outputPrefix=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n} \
            --IsOverwriteVarianceRatioFile=TRUE \
            --LOCO=FALSE &

    done
done



#continuous phenotype
n=179176
group=1
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -v /media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/:/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/ \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step1_group${group}_${n}.log -v \
        step1_fitNULLGLMM.R \
            --sparseGRMFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx \
            --sparseGRMSampleIDFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx.sampleIDs.txt \
            --useSparseGRMtoFitNULL=TRUE \
            --plinkFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_oddchr_combined_4000SNP \
            --phenoFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/mock_cont_pheno.txt \
            --phenoCol=${colname} \
            --covarColList=x1,x2,PC1,PC2,PC3,PC4,PC5,PC6,PC7,PC8,PC9,PC10 \
            --qCovarColList=x2 \
            --sampleIDColinphenoFile=IND_ID \
            --traitType=quantitative \
            --isCateVarianceRatio=TRUE \
            --nThreads=1 \
            --outputPrefix=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}_cont \
            --IsOverwriteVarianceRatioFile=TRUE \
            --LOCO=FALSE
#dense GRM
n=179176
group=1
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -v /media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/:/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/ \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step1_group${group}_${n}_dense.log -v \
        step1_fitNULLGLMM.R \
            --sparseGRMFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx \
            --sparseGRMSampleIDFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx.sampleIDs.txt \
            --useSparseGRMtoFitNULL=FALSE \
            --plinkFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_oddchr_combined_4000SNP \
            --phenoFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/mock_cont_pheno.txt \
            --phenoCol=${colname} \
            --covarColList=x1,x2,PC1,PC2,PC3,PC4,PC5,PC6,PC7,PC8,PC9,PC10 \
            --qCovarColList=x2 \
            --sampleIDColinphenoFile=IND_ID \
            --traitType=quantitative \
            --isCateVarianceRatio=TRUE \
            --nThreads=1 \
            --outputPrefix=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}_cont_dense \
            --IsOverwriteVarianceRatioFile=TRUE \
            --LOCO=FALSE


#PCG

colname=y
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -v /media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/:/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/ \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.4.5 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step1_group${group}_${n}_PCG.log -v \
        step1_fitNULLGLMM.R \
            --sparseGRMFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx \
            --sparseGRMSampleIDFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx.sampleIDs.txt \
            --useSparseGRMtoFitNULL=TRUE \
            --usePCGwithSparseGRM=TRUE \
            --plinkFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_oddchr_combined_4000SNP \
            --phenoFile=/media/leelabsg-storage0/eunjae/Meta-code/Inflation_eval/whole_WES/seed_1_WES_200k_WB_tau_1_prev_0.01.pheno.evenChr_pca \
            --phenoCol=${colname} \
            --covarColList=x1,x2,PC1,PC2,PC3,PC4,PC5,PC6,PC7,PC8,PC9,PC10 \
            --sampleIDColinphenoFile=IND_ID \
            --traitType=binary \
            --isCateVarianceRatio=TRUE \
            --nThreads=1 \
            --outputPrefix=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}_PCG \
            --IsOverwriteVarianceRatioFile=TRUE \
            --LOCO=FALSE
    done
done

# %% [markdown]
# ## SAIGE step2

# %%
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step2_group${group}_${n}.log -v \
        step2_SPAtests.R \
            --bedFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bed \
            --bimFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bim \
            --famFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.fam \
            --AlleleOrder=alt-first \
            --SAIGEOutputFile=Meta-code/computational_cost/meta-saige/step2_res/group${group}_${n}.txt \
            --chrom=2 \
            --minMAF=0 \
            --minMAC=0.5 \
            --is_overwrite_output=TRUE \
            --GMMATmodelFile=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}.rda \
            --maxMAF=0.01 \
            --is_Firth_beta=TRUE \
            --pCutoffforFirth=0.05 \
            --is_output_moreDetails=TRUE \
            --MACCutoff_to_CollapseUltraRare 0 \
            --max_MAC_for_ER=10 \
            --sparseGRMFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx \
            --sparseGRMSampleIDFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step0_res/group${group}_${n}_relatednessCutoff_0.125_2000_randomMarkersUsed.sparseGRM.mtx.sampleIDs.txt \
            --maxMAF_in_groupTest=0.01 \
            --is_output_markerList_in_groupTest=TRUE \
            --is_single_in_groupTest=TRUE \
            --max_MAC_for_ER=10 \
            --rangestoIncludeFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/Regionfile.tsv \
            --LOCO=FALSE
    done
done

mkdir -p /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step2_full_res
#without sparse GRM
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs_old/step2_group${group}_${n}.log -v \
        step2_SPAtests.R \
            --bedFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bed \
            --bimFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bim \
            --famFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.fam \
            --AlleleOrder=alt-first \
            --SAIGEOutputFile=Meta-code/computational_cost/meta-saige/step2_full_res/group${group}_${n}.txt \
            --chrom=2 \
            --minMAF=0 \
            --minMAC=0.5 \
            --is_overwrite_output=TRUE \
            --GMMATmodelFile=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}.rda \
            --maxMAF=0.01 \
            --is_Firth_beta=TRUE \
            --pCutoffforFirth=0.05 \
            --is_output_moreDetails=TRUE \
            --MACCutoff_to_CollapseUltraRare 0 \
            --max_MAC_for_ER=10 \
            --maxMAF_in_groupTest=0.01 \
            --is_output_markerList_in_groupTest=TRUE \
            --is_single_in_groupTest=TRUE \
            --max_MAC_for_ER=10 \
            --rangestoIncludeFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/Regionfile.tsv \
            --LOCO=FALSE
    done
done


#Continuous phenotype
n=179176
group=1

        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs_old/step2_group${group}_${n}.log -v \
        step2_SPAtests.R \
            --bedFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bed \
            --bimFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bim \
            --famFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.fam \
            --AlleleOrder=alt-first \
            --SAIGEOutputFile=Meta-code/computational_cost/meta-saige/step2_full_res/group${group}_${n}_cont.txt \
            --chrom=2 \
            --minMAF=0 \
            --minMAC=0.5 \
            --is_overwrite_output=TRUE \
            --GMMATmodelFile=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}_cont.rda \
            --maxMAF=0.01 \
            --is_Firth_beta=TRUE \
            --pCutoffforFirth=0.05 \
            --is_output_moreDetails=TRUE \
            --MACCutoff_to_CollapseUltraRare 0 \
            --max_MAC_for_ER=10 \
            --maxMAF_in_groupTest=0.01 \
            --is_output_markerList_in_groupTest=TRUE \
            --is_single_in_groupTest=TRUE \
            --max_MAC_for_ER=10 \
            --rangestoIncludeFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/Regionfile.tsv \
            --LOCO=FALSE

#dense GRM
n=179176
group=1

        docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
        -w /media/leelabsg-storage0/eunjae/ wzhou88/saige:1.3.3 \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs_old/step2_group${group}_${n}_dense.log -v \
        step2_SPAtests.R \
            --bedFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bed \
            --bimFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bim \
            --famFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/genotype/group${group}_${n}_chr2.fam \
            --AlleleOrder=alt-first \
            --SAIGEOutputFile=Meta-code/computational_cost/meta-saige/step2_full_res/group${group}_${n}_cont_dense.txt \
            --chrom=2 \
            --minMAF=0 \
            --minMAC=0.5 \
            --is_overwrite_output=TRUE \
            --GMMATmodelFile=Meta-code/computational_cost/meta-saige/step1_res/group${group}_${n}_cont_dense.rda \
            --maxMAF=0.01 \
            --is_Firth_beta=TRUE \
            --pCutoffforFirth=0.05 \
            --is_output_moreDetails=TRUE \
            --MACCutoff_to_CollapseUltraRare 0 \
            --max_MAC_for_ER=10 \
            --maxMAF_in_groupTest=0.01 \
            --is_output_markerList_in_groupTest=TRUE \
            --is_single_in_groupTest=TRUE \
            --max_MAC_for_ER=10 \
            --rangestoIncludeFile=/media/leelabsg-storage0/eunjae/Meta-code/computational_cost/Regionfile.tsv \
            --LOCO=FALSE

# %% [markdown]
# ## SAIGE step3

# %%
docker run -v /media/leelabsg-storage0/eunjae/Meta-code/computational_cost:/media/leelabsg-storage0/eunjae/Meta-code/computational_cost \
    -w /media/leelabsg-storage0/eunjae/ \
    -it wzhou88/saige:1.3.2


export MKL_NUM_THREADS=1;export MKL_DYNAMIC=false; export OMP_NUM_THREADS=1; export OMP_DYNAMIC=false;
for n in 10000 50000 100000 179176
do
    for group in {1..3}
    do
        # /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step3_group${group}_${n}.log -v \
        /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs_old/step3_group${group}_${n}.log -v \
        step3_LDmat.R \
            --bedFile=Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bed \
            --bimFile=Meta-code/computational_cost/genotype/group${group}_${n}_chr2.bim \
            --famFile=Meta-code/computational_cost/genotype/group${group}_${n}_chr2.fam \
            --AlleleOrder=alt-first \
            --SAIGEOutputFile=Meta-code/computational_cost/meta-saige/step3_res/group${group}_${n} \
            --chrom=2 \
            --groupFile=Meta-code/computational_cost/TTN_groupfile.txt \
            --annotation_in_groupTest='missense;lof;synonymous' \
            --is_overwrite_output=TRUE \
            --maxMAF_in_groupTest=0.001 &> /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step3_group${group}_${n}.log
            # --maxMAF_in_groupTest=0.01 &> /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/step3_group${group}_${n}.log
    done
done

# %% [markdown]
# ## MetaSAIGE

# %%
export MKL_NUM_THREADS=1;export MKL_DYNAMIC=false; export OMP_NUM_THREADS=1; export OMP_DYNAMIC=false;
for n in 10000 50000 100000 179176
do
    /usr/bin/time -o /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/logs/meta${n}.log -v \
    Rscript /data/home/parkeunj/SAIGE_META/inst/scripts/RV_meta_GC.R \
        --num_cohorts 3 \
        --chr 2 \
        --col_co 10 \
        --info_file_path /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group1_${n}.marker_info.txt \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group2_${n}.marker_info.txt \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group3_${n}.marker_info.txt \
        \
        --gene_file_prefix /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group1_${n}_ \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group2_${n}_ \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step3_res/group3_${n}_ \
        \
        --gwas_path /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step2_res/group1_${n}.txt \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step2_res/group2_${n}.txt \
        /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/step2_res/group3_${n}.txt \
        \
        --trait_type binary \
        --verbose TRUE \
        --output_prefix /media/leelabsg-storage0/eunjae/Meta-code/computational_cost/meta-saige/meta_res_${n}.txt
done
